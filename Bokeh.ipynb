# %%
pip install bokeh

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook() # This will able to print graph inside our notebook

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_7284178065621758601 = autoviz.get_df('df_7284178065621758601')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_7284178065621758601, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8589544623375557191 = autoviz.get_df('df_8589544623375557191')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
# ...

# %%
output_file('test.html')

p = figure(title = 'test flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="bc73bdc3-59ec-4d93-9311-3e18fdec271f" data-root-id="p1001" style="display: contents;"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file("line.html")
p = figure(title = "line_graph")
p.line(x,y)
show(p)
# Out:
#   <div id="a2dc1c47-e5cd-4d08-8490-e82646cf5d15" data-root-id="p1192" style="display: contents;"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file("line.html")
p = figure(title = "line_graph")
p.scatter(x,y)
show(p)
# Out:
#   <div id="e5017998-bad1-4d30-8ac8-1454b20e8f30" data-root-id="p1424" style="display: contents;"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file("line.html")
p = figure(title = "line_graph")
p.scatter(x,y, size = 20, fill_color = 'red', legend_label = "This is my data points")
show(p)
# Out:
#   <div id="deb4a185-8889-4810-8fed-4404e6054355" data-root-id="p2180" style="display: contents;"></div>
